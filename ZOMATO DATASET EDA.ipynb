# %% [markdown]
# ### ZOMATO DATASET EDA

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns  
import matplotlib.pyplot as plt

# %% [markdown]
# ### DATA PREPARATION

# %%
# Importing the datasets required
df=pd.read_csv('Zomato.csv',encoding='ISO-8859-1') # Encoding parameter is specified to read the file
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape # Number of rows and columns
# Out:
# (9551, 21)

# %%
df.columns # Checking the columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info() # Checking which columns are of which datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe() # Gives the relation between columns
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.isnull().sum() # To check how many null values are present. In this case, there are 9 null values in the column-Cuisines.
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.duplicated().sum() # To check the number of duplicates
# Out:
# 0

# %%
# Loading Country Code Dataset
df2=pd.read_csv('Country-Code.csv')
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# Now we need to check for common columns in both datasets to merge them together
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
# Finding the common columns
common_columns = df.columns.intersection(df2.columns)
if not common_columns.empty:
    print("Common columns:", common_columns)
else:
    print("No common columns.")
# Out:
# Common columns: Index(['Country Code'], dtype='object')

# %%
# Merging the two data sets and forming the final data set to be used
df_final=pd.merge(df,df2,on="Country Code")
df_final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ### DATA VISUALISATION

# %%
# Data Visualisation involving pie chart
top_countries = df_final['Country'].value_counts().nlargest(5)
top_countries.plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.title('Pie chart for Top 5 Countries')
plt.show()

# %% [raw]
# INFERENCE:
# WE CAN SEE THAT THE TOP 5 COUNTRIES IN TRANSACTIONS ARE AS FOLLOWS: INDIA, UNITED STAES, UNITED KINGDOM, BRAZIL AND UAE. INDIA HOLDS THE UNDISPUTED MAJORITY IN TERMS OF RECORDS OR TRANSACTIONS.

# %%
# Using groupby to see the ratings in ascending order
rating = df_final.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index(name='Rating count')
rating.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
# Last values of rating 
rating.tail()
# Out:
#     Aggregate rating Rating color Rating text  Rating count
# 28               4.5   Dark Green   Excellent            95
# 29               4.6   Dark Green   Excellent            78
# 30               4.7   Dark Green   Excellent            42
# 31               4.8   Dark Green   Excellent            25
# 32               4.9   Dark Green   Excellent            61

# %%
# Seeing the different categories within rating
rating['Rating text'].unique()
# Out:
# array(['Not rated', 'Poor', 'Average', 'Good', 'Very Good', 'Excellent'],
#       dtype=object)

# %%
rating
# Out:
#     Aggregate rating Rating color Rating text  Rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [raw]
# INFERENCE:
# Ratings ranging from 4.5 to 4.9 is categorised as "Excellent."
# Ratings between 4.0 and 3.4 is categorised as"Very Good."
# Ratings falling between 3.5 and 3.9 is categorised as"Good."
# Ratings within the range of 3.0 to 3.4 is categorised as "Average."
# Ratings spanning from 2.5 to 2.9 is categorised as "Average."
# Ratings within the range of 2.0 to 2.4 remain unchanged and is categorised as"Poor."

# %%
# From the rating dataset, we can see that orange is the most given rating, followed by red
colors = ['lightcyan', 'red', 'orange', 'yellow', 'green', 'darkgreen']
sns.countplot(x="Rating color",data=rating,palette=colors)
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
# Finding the top countries with positive rating and its count
Excellent=df_final[df_final["Rating color"]=="Dark Green"].groupby("Country").size().sort_values(ascending=False).reset_index().rename(columns={0:"Rating_count"})
Excellent
# Out:
#            Country  Rating_count
# 0            India           116
# 1    United States            68
# 2   United Kingdom            23
# 3              UAE            18
# 4           Brazil            16
# 5      New Zealand            12
# 6      Phillipines            12
# 7     South Africa            12
# 8           Turkey            10
# 9        Indonesia             7
# 10           Qatar             4
# 11       Sri Lanka             2
# 12       Australia             1

# %%
plt.figure(figsize=(20, 5))
sns.barplot(x="Country", y="Rating_count" ,data=Excellent,palette=colors)
# Out:
# <Axes: xlabel='Country', ylabel='Rating_count'>

# %%
sns.lineplot(x='Country',y='Rating_count',data=Excellent,errorbar=None,color='red')
plt.xlabel('Country')
plt.ylabel('Rating_count')
plt.title('Country VS Rating_count')
plt.show()

# %%
# Finding the top countries with least ratings and their count
poor=df_final[df_final["Rating color"]=="Red"].groupby("Country").size().sort_values(ascending=False).reset_index().rename(columns={0:"Rating_count"})
poor
# Out:
#          Country  Rating_count
# 0          India           180
# 1  United States             2
# 2      Australia             1
# 3    New Zealand             1
# 4      Sri Lanka             1
# 5            UAE             1

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="Country", y="Rating_count" ,data=poor,palette=colors)
# Out:
# <Axes: xlabel='Country', ylabel='Rating_count'>

# %%
sns.lineplot(x='Country',y='Rating_count',data=poor,errorbar=None,color='blue')
plt.xlabel('Country')
plt.ylabel('Rating_count')
plt.title('Country VS Rating_count')
plt.show()

# %% [raw]
# INFERENCE:
# WE cAN SEE THAT FOR THE TOP AND BOTTOM RATINGS, INDIA IS IN THE LEAD, FOLLOWED BY UNITED STATES IN BOTH SECTIONS. THIS MAY BE DUE TO THE IMMENSE REACH OF ZOMATO IN INDIA AND UNITED STATES.

# %%
# Best city with top rated restaurents
Top=df_final.groupby(["Votes","Restaurant Name","City"]).size().reset_index().tail(50).rename(columns={0:"Rating_count"})
Top
# Out:
#       Votes                       Restaurant Name       City  Rating_count
# 9353   2620                    Naturals Ice Cream  New Delhi             1
# 9354   2639                               Berco's  New Delhi             1
# 9355   2662                          Joey's Pizza     Mumbai             1
# 9356   2689  Parikrama - The Revolving Restaurant  New Delhi             1
# 9357   2724                       QD's Restaurant  New Delhi             1
# 9358   2777                             Big Chill  New Delhi             1
# 9359   2806                      Pirates of Grill    Gurgaon             1
# 9360   2826                  Bukhara - ITC Maurya  New Delhi             1
# 9361   2843                  SodaBottleOpenerWala    Gurgaon             1
# 9362   2847                       Barbeque Nation       Pune             1
# 9363   2860                           Khan Chacha  New Delhi             1
# ...

# %%
plt.figure(figsize=(15, 5))
top_final=Top.groupby(["City"]).size().sort_values(ascending=False).reset_index(name="Rating_count")
sns.barplot(x="City",y="Rating_count", data= top_final,palette=colors)
# Out:
# <Axes: xlabel='City', ylabel='Rating_count'>

# %%
sns.lineplot(x='City',y='Rating_count',data=top_final,errorbar=None,color='purple')
plt.xlabel('City')
plt.ylabel('Rating_count')
plt.title('City VS Rating_count')
plt.show()

# %% [raw]
# INFERENCE:
# WE CAN SEE THAT NEW DELHI IS THE CITY THAT CLAIMS THE TITLE FOR THE CITY WITH THE MOST TOP RATED RESTAURENTS, FOLLOWED BY BANGALORE AND GURGAON. PUNE IS AT THE BOTTOM OF THE LIST.
